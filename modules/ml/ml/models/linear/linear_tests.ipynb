# %%
from lib import *
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Linear Simple :

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
])
Y = np.array([
      1,
      -1,
      -1
])

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.01,
      20000,
      True
)
# Out:
# Weights before train: [-0.5787412139367869, -0.736563001585647, -0.2681121421935848]
# Weights after train: [-0.26238265201259797, -2.9010659512253834, 5.883036955878429]

# %%
predict_linear_model(linear_model, X[0], True)
# Out:
# 0.9913514463341623

# %%
predict_linear_model(linear_model, X[1], True)
# Out:
# -0.9975161559952734

# %%
predict_linear_model(linear_model, X[2], True)
# Out:
# -0.9985295782409007

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.01,
      100000,
      True
)
# Out:
# Weights before train: [0.16602684861321348, -0.28605552279514423, 0.5964780296809375]
# Weights after train: [-7.223216870187689, -6.734132976634633, 26.553224406751642]

# %%
predict_linear_model(linear_model, np.array([1.5, 1.5]), True)
# Out:
# 0.9999735767249147

# %%
predict_linear_model(linear_model, np.array([2.5, 2.5]), True)
# Out:
# -0.9999998860097932

# %%
predict_linear_model(linear_model, np.array([1.9, 1.9]), True)
# Out:
# 0.03424630023634745

# %%
predict_linear_model(linear_model, np.array([2, 2]), True)
# Out:
# -0.8767347963407138

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### XOR

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.01,
      100000,
      True
)
# Out:
# Weights before train: [-0.5147570654281699, 0.5812849549817218, 0.7189989100111989]
# Weights after train: [0.08471749329196702, -0.12328017779620959, -0.06826469133439804]

# %%
predict_linear_model(linear_model, np.array([0, 0]), True)
# Out:
# -0.06815884925278276

# %%
predict_linear_model(linear_model, np.array([0, 1]), True)
# Out:
# -0.189236187121986

# %%
predict_linear_model(linear_model, np.array([1, 0]), True)
# Out:
# 0.01645131755624239

# %%
predict_linear_model(linear_model, np.array([1, 1]), True)
# Out:
# -0.1064228478624905

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.001,
      100000,
      True
)
# Out:
# Weights before train: [-0.2810349245970789, 0.2406409890244965, -0.02877003244341081]
# Weights after train: [-0.09774052154042598, -0.056721657060057926, 0.08907734879148316]

# %%
predict_linear_model(linear_model, np.array([0, 0]), True)
# Out:
# 0.08884249130070812

# %%
predict_linear_model(linear_model, np.array([-0.75, 0.75]), True)
# Out:
# 0.11927105343684778

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Multi Linear 3 classes :

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else
              [0, 0, 0]for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %%
Y_A = np.array(list(map(lambda category: 1 if category[0] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == -1, enumerate(X)))))[:,1], color='red')

plt.show()
plt.clf()

# %%
Y_B = np.array(list(map(lambda category: 1 if category[1] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_B[c[0]] == 1, enumerate(X)))))[:, 0],
            np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_B[c[0]] == 1, enumerate(X)))))[:, 1], color='blue')
plt.scatter(np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_B[c[0]] == -1, enumerate(X)))))[:, 0],
            np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_B[c[0]] == -1, enumerate(X)))))[:, 1], color='red')

plt.show()
plt.clf()

# %%
plt.clf()
Y_C = np.array(list(map(lambda category: 1 if category[2] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_C[c[0]] == 1, enumerate(X)))))[:, 0],
            np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_C[c[0]] == 1, enumerate(X)))))[:, 1], color='blue')
plt.scatter(np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_C[c[0]] == -1, enumerate(X)))))[:, 0],
            np.array(list(map(lambda elt: elt[1], filter(lambda c: Y_C[c[0]] == -1, enumerate(X)))))[:, 1], color='red')

plt.show()
plt.clf()

# %%
linear_model_A = create_linear_model(3)
linear_model_B = create_linear_model(3)
linear_model_C = create_linear_model(3)

# %%
train_linear_model(
      linear_model_A,
      X,
      Y_A,
      0.001,
      50000,
      True
)

train_linear_model(
      linear_model_B,
      X,
      Y_B,
      0.001,
      50000,
      True
)

train_linear_model(
      linear_model_C,
      X,
      Y_C,
      0.001,
      50000,
      True
)
# Out:
# Weights before train: [-0.873470268766225, -0.39909262733357753, 0.0010116433015023851]
# Weights after train: [-18.053722201622975, -17.770069093381696, -9.026610603897886]
# Weights before train: [0.4342459708089059, 0.7658586258676481, 0.4653961889042475]
# Weights after train: [-0.08133638954755548, 25.98009374632905, 0.41052596721398193]
# Weights before train: [0.2232898810435806, 0.026080327625527033, -0.09306375991326732]
# Weights after train: [16.22750322697061, -16.401408783233983, -8.461304459262308]

# %%
def predict_3_classes(model_A, model_B, model_C, sample):
      return np.array([
            predict_linear_model(model_A, sample, True),
            predict_linear_model(model_B, sample, True),
            predict_linear_model(model_C, sample, True)
      ])

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([-0.5, -0.5])
)
# Out:
# array([ 0.99999996, -1.        , -0.99999989])

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([0., 0.75])
)
# Out:
# array([-1.,  1., -1.])

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([0.5, -0.5])
)
# Out:
# array([-0.99999998, -1.        ,  0.9999997 ])

# %%
destroy_linear_model(linear_model_A)
destroy_linear_model(linear_model_B)
destroy_linear_model(linear_model_C)
# Out:
# 0

# %% [markdown]
# ### Multi Cross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %%
Y_A = np.array(list(map(lambda category: 1 if category[0] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_A[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %%
Y_B = np.array(list(map(lambda category: 1 if category[1] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_B[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_B[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_B[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_B[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %%
Y_C = np.array(list(map(lambda category: 1 if category[2] == 1 else -1, Y)))

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_C[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_C[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_C[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y_C[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %%
linear_model_A = create_linear_model(3)
linear_model_B = create_linear_model(3)
linear_model_C = create_linear_model(3)

# %%
train_linear_model(
      linear_model_A,
      X,
      Y_A,
      0.002,
      50000,
      True
)

train_linear_model(
      linear_model_B,
      X,
      Y_B,
      0.002,
      50000,
      True
)

train_linear_model(
      linear_model_C,
      X,
      Y_C,
      0.002,
      50000,
      True
)
# Out:
# Weights before train: [0.03587570057438816, 0.4332509054032565, -0.21548563593017356]
# Weights after train: [-0.18642038996961746, 0.32445236105761865, -0.5466727613207129]
# Weights before train: [0.7216571000811882, 0.7598951700352288, 0.5446409821456646]
# Weights after train: [0.24681104877126875, -0.24864431576829182, -0.6009119421212049]
# Weights before train: [0.04596264282734808, 0.9867933237149593, -0.38928070350301835]
# Weights after train: [-0.08878215580034995, -0.11038792823597426, 0.05215558484078915]

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([-0.9, 0.9])
)
# Out:
# array([-0.08666929, -0.78056766,  0.03269873])

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([-0.6, 0.9])
)
# Out:
# array([-0.14185033, -0.74992272,  0.00607567])

# %%
predict_3_classes(
      linear_model_A,
      linear_model_B,
      linear_model_C,
      np.array([-0.6, 0.6])
)
# Out:
# array([-0.23563659, -0.71541304,  0.03917207])

# %%
destroy_linear_model(linear_model_A)
destroy_linear_model(linear_model_B)
destroy_linear_model(linear_model_C)
# Out:
# 0

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(2)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.01,
      5000,
      False
)
# Out:
# Weights before train: [0.5959786456361642, -0.08131790270540984]
# Weights after train: [1.0002478172466467, 0.9995861154976068]

# %%
predict_linear_model(linear_model, np.array([1]), False)
# Out:
# 1.9998339327442536

# %%
predict_linear_model(linear_model, np.array([2]), False)
# Out:
# 3.0000817499909003

# %%
predict_linear_model(linear_model, np.array([3]), False)
# Out:
# 4.0003295672375465

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Non Linear Simple 2D :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(2)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.01,
      5000,
      False
)
# Out:
# Weights before train: [0.9247034277687511, -0.010586498388801768]
# Weights after train: [0.21542402047458584, 2.0052498193515356]

# %%
predict_linear_model(linear_model, np.array([1]), False)
# Out:
# 2.220673839826121

# %%
predict_linear_model(linear_model, np.array([2]), False)
# Out:
# 2.4360978603007073

# %%
predict_linear_model(linear_model, np.array([3]), False)
# Out:
# 2.651521880775293

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Linear Simple 3D :

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.002,
      5000,
      False
)
# Out:
# Weights before train: [-0.6797812212712357, 0.6846701027255717, -0.5351931544928177]
# Weights after train: [0.287626637159218, 0.8459253147150926, 0.7871593413164152]

# %%
predict_linear_model(linear_model, np.array([1, 1]), False)
# Out:
# 1.9207112931907258

# %%
predict_linear_model(linear_model, np.array([2, 2]), False)
# Out:
# 3.0542632450650364

# %%
predict_linear_model(linear_model, np.array([3, 1]), False)
# Out:
# 2.4959645675091617

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Linear Tricky 3D :

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.002,
      5000,
      False
)
# Out:
# Weights before train: [-0.4723058660977535, -0.3448009888793564, 0.6452949605292604]
# Weights after train: [0.43247908234515825, 0.5599839595635495, 0.018091907834647026]

# %%
predict_linear_model(linear_model, np.array([4, 4]), False)
# Out:
# 3.987944075469478

# %%
destroy_linear_model(linear_model)
# Out:
# 0

# %% [markdown]
# ### Non Linear Simple 3D :

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
linear_model = create_linear_model(3)

# %%
train_linear_model(
      linear_model,
      X,
      Y,
      0.002,
      10000,
      False
)
# Out:
# Weights before train: [0.09540075527650904, 0.7111887463723328, 0.1378653247667203]
# Weights after train: [-0.058898715146405746, -0.9831716516055441, 0.4785614240955181]

# %%
predict_linear_model(linear_model, np.array([0, 0]), False)
# Out:
# 0.4785614240955181
