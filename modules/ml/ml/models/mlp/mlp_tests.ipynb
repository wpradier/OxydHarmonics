# %%
from modules.ml.ml.models.mlp.lib import *
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Linear Simple :

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
])
Y = np.array([
      [1],
      [-1],
      [-1]
])

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.01,
      1000,
      True,
      b"MLP_2_1_linearsimple"
)

# %%
predict_mlp_model(mlp_model, X[0], True, 1)
# Out:
# array([0.71123569])

# %%
predict_mlp_model(mlp_model, X[1], True, 1)
# Out:
# array([-0.88500939])

# %%
predict_mlp_model(mlp_model, X[2], True, 1)
# Out:
# array([-0.8859537])

# %%
save_mlp_model(mlp_model, b"linear_simple_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.01,
      100,
      True,
      b"MLP_2_1_linearmultiple"
)

# %%
predict_mlp_model(mlp_model, np.array([1.5, 1.5]), True, 1)
# Out:
# array([0.79025389])

# %%
predict_mlp_model(mlp_model, np.array([2.5, 2.5]), True, 1)
# Out:
# array([-0.88897036])

# %%
predict_mlp_model(mlp_model, np.array([1.9, 1.9]), True, 1)
# Out:
# array([0.0763178])

# %%
predict_mlp_model(mlp_model, np.array([2, 2]), True, 1)
# Out:
# array([-0.17075454])

# %%
save_mlp_model(mlp_model, b"linear_multiple_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### XOR

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([[1], [1], [-1], [-1]])

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.01,
      5000,
      True,
      b"MLP_2_2_1_xor"
)

# %%
predict_mlp_model(mlp_model, np.array([0, 0]), True, 1)
# Out:
# array([-0.96634964])

# %%
predict_mlp_model(mlp_model, np.array([0, 1]), True, 1)
# Out:
# array([0.95989122])

# %%
predict_mlp_model(mlp_model, np.array([1, 0]), True, 1)
# Out:
# array([0.95857571])

# %%
predict_mlp_model(mlp_model, np.array([1, 1]), True, 1)
# Out:
# array([-0.97078936])

# %%
save_mlp_model(mlp_model, b"xor_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 4, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y.reshape((len(Y), 1)),
      0.001,
      5000,
      True,
      b"MLP_2_4_1_cross"
)

# %%
predict_mlp_model(mlp_model, np.array([0, 0]), True, 1)
# Out:
# array([1.])

# %%
predict_mlp_model(mlp_model, np.array([-0.75, 0.75]), True, 1)
# Out:
# array([-0.99839885])

# %%
predict_mlp_model(mlp_model, np.array([0, 0.75]), True, 1)
# Out:
# array([0.99999639])

# %%
predict_mlp_model(mlp_model, np.array([0.75, 0.75]), True, 1)
# Out:
# array([-0.99909832])

# %%
save_mlp_model(mlp_model, b"cross_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Multi Linear 3 classes :

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, -1, -1] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, 1, -1] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, -1, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else
              [-1, -1, -1]for p in X])

X = X[[not np.all(arr == [-1, -1, -1]) for arr in Y]]
Y = Y[[not np.all(arr == [-1, -1, -1]) for arr in Y]]

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 3]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.001,
      5000,
      True,
      b"MLP_2_3_multilinear3"
)

# %%
predict_mlp_model(mlp_model, np.array([-0.5, -0.5]), True, 3)
# Out:
# array([ 0.9946138 , -0.99989733, -0.99814999])

# %%
predict_mlp_model(mlp_model, np.array([0., 0.75]), True, 3)
# Out:
# array([-0.99999986,  0.99999809, -0.99999981])

# %%
predict_mlp_model(mlp_model, np.array([0.5, -0.5]), True, 3)
# Out:
# array([-0.99751678, -0.99984728,  0.99582873])

# %%
save_mlp_model(mlp_model, b"multilinear3_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Multi Cross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, -1, -1] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [-1, 1, -1] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [-1, -1, 1] for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 30, 30, 3]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.001,
      6000,
      True,
      b"MLP_2_30_30_3_multicross"
)

# %%
predict_mlp_model(mlp_model, np.array([-0.9, 0.9]), True, 3)
# Out:
# array([ 0.99930979, -0.99973717, -0.99999972])

# %%
predict_mlp_model(mlp_model, np.array([-0.6, 0.9]), True, 3)
# Out:
# array([-0.98728927, -0.99998336,  0.9998079 ])

# %%
predict_mlp_model(mlp_model, np.array([-0.6, 0.6]), True, 3)
# Out:
# array([-0.99999929,  0.99110734, -0.98541281])

# %%
save_mlp_model(mlp_model, b"multicross_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([1, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y.reshape((len(Y), 1)),
      0.01,
      5000,
      False,
      b"MLP_1_1_simple2D"
)

# %%
predict_mlp_model(mlp_model, np.array([1]), False, 1)
# Out:
# array([1.99994097])

# %%
predict_mlp_model(mlp_model, np.array([2]), False, 1)
# Out:
# array([3.00003471])

# %%
predict_mlp_model(mlp_model, np.array([3]), False, 1)
# Out:
# array([4.00012844])

# %%
save_mlp_model(mlp_model, b"linearsimple2D_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Non Linear Simple 2D :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      [2],
      [3],
      [2.5]
])

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([1, 3, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.007,
      13000,
      False,
      b"MLP_1_3_1_nonlinearsimple2D"
)

# %%
predict_mlp_model(mlp_model, np.array([1]), False, 1)
# Out:
# array([2.0005766])

# %%
predict_mlp_model(mlp_model, np.array([2]), False, 1)
# Out:
# array([2.9967921])

# %%
predict_mlp_model(mlp_model, np.array([3]), False, 1)
# Out:
# array([2.50193629])

# %%
save_mlp_model(mlp_model, b"nonlinearsimple2D_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0

# %% [markdown]
# ### Linear Simple 3D :

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      [2],
      [3],
      [2.5]
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.002,
      5000,
      False,
      b"MLP_2_1_linearsimple3D"
)

# %%
predict_mlp_model(mlp_model, np.array([1, 1]), False, 1)
# Out:
# array([1.9780787])

# %%
predict_mlp_model(mlp_model, np.array([2, 2]), False, 1)
# Out:
# array([3.01077493])

# %%
predict_mlp_model(mlp_model, np.array([3, 1]), False, 1)
# Out:
# array([2.49737535])

# %%
save_mlp_model(mlp_model, b"linearsimple3D_MLP")

# %%
destroy_mlp_model(mlp_model)

# %% [markdown]
# ### Linear Tricky 3D :

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      [1],
      [2],
      [3]
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.002,
      5000,
      False,
      b"MLP_2_1_lineartricky3D"
)

# %%
predict_mlp_model(mlp_model, np.array([4, 4]), False, 1)
# Out:
# array([3.99517157])

# %%
save_mlp_model(mlp_model, b"lineartricky3D_MLP")

# %%
destroy_mlp_model(mlp_model)

# %% [markdown]
# ### Non Linear Simple 3D :

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      [2],
      [1],
      [-2],
      [-1]
])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(X[:, 0], X[:, 1], Y)
plt.show()
plt.clf()

# %%
mlp_model = create_mlp_model(np.array([2, 2, 1]))

# %%
train_mlp_model(
      mlp_model,
      X,
      Y,
      0.002,
      15000,
      False,
      b"MLP_2_2_1_nonlinearsimple3D"
)

# %%
predict_mlp_model(mlp_model, np.array([0, 0]), False, 1)
# Out:
# array([-0.99999983])

# %%
predict_mlp_model(mlp_model, np.array([0, 1]), False, 1)
# Out:
# array([0.99999989])

# %%
predict_mlp_model(mlp_model, np.array([1, 0]), False, 1)
# Out:
# array([1.99999985])

# %%
predict_mlp_model(mlp_model, np.array([1, 1]), False, 1)
# Out:
# array([-1.99999976])

# %%
save_mlp_model(mlp_model, b"nonlinearsimple3D_MLP")

# %%
destroy_mlp_model(mlp_model)
# Out:
# 0
